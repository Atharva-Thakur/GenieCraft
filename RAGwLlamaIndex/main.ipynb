# %%
# %pip install -Uq llama-index
# %pip install llama-index-llms-ollama
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-llms-ollama
#   Downloading llama_index_llms_ollama-0.3.6-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.11.22)
# Collecting ollama>=0.3.0 (from llama-index-llms-ollama)
#   Downloading ollama-0.3.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.10.10)
# Requirement already satisfied: dataclasses-json in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2024.10.0)
# Requirement already satisfied: httpx in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.17.1)
# Requirement already satisfied: anyio in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (4.4.0)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.0.5)
# Requirement already satisfied: idna in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.8)
# Requirement already satisfied: sniffio in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: click in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.2.0)
# Downloading llama_index_llms_ollama-0.3.6-py3-none-any.whl (5.9 kB)
# Downloading ollama-0.3.3-py3-none-any.whl (10 kB)
# Installing collected packages: ollama, llama-index-llms-ollama
# Successfully installed llama-index-llms-ollama-0.3.6 ollama-0.3.3
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %ls
# Out:
# data/  main.ipynb

# %%
from llama_index.core import KeywordTableIndex, SimpleDirectoryReader
from llama_index.llms.ollama import Ollama

documents = SimpleDirectoryReader("data").load_data()
llm = Ollama(model="steamdj/llama3.1-cpu-only", request_timeout=120.0)
index = KeywordTableIndex.from_documents(documents, llm=llm)
# get response from query
query_engine = index.as_query_engine()
response = query_engine.query(
    "What did the author do after his time at Y Combinator?"
)
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[14], line 6
#       4 documents = SimpleDirectoryReader("data").load_data()
#       5 llm = Ollama(model="steamdj/llama3.1-cpu-only", request_timeout=120.0)
# ----> 6 index = KeywordTableIndex.from_documents(documents, llm=llm)
#       7 # get response from query
#       8 query_engine = index.as_query_engine()
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/base.py:119, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     110     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     112 nodes = run_transformations(
#     113     documents,  # type: ignore
#     114     transformations,
#     115     show_progress=show_progress,
#     116     **kwargs,
#     117 )
# --> 119 return cls(
#     120     nodes=nodes,
#     121     storage_context=storage_context,
#     122     callback_manager=callback_manager,
#     123     show_progress=show_progress,
#     124     transformations=transformations,
#     125     **kwargs,
#     126 )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/keyword_table/base.py:90, in BaseKeywordTableIndex.__init__(self, nodes, objects, index_struct, llm, keyword_extract_template, max_keywords_per_chunk, use_async, show_progress, **kwargs)
#      86 self.keyword_extract_template = self.keyword_extract_template.partial_format(
#      87     max_keywords=self.max_keywords_per_chunk
#      88 )
#      89 self._use_async = use_async
# ---> 90 super().__init__(
#      91     nodes=nodes,
#      92     index_struct=index_struct,
#      93     show_progress=show_progress,
#      94     objects=objects,
#      95     **kwargs,
#      96 )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/base.py:77, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      75 if index_struct is None:
#      76     nodes = nodes or []
# ---> 77     index_struct = self.build_index_from_nodes(
#      78         nodes + objects,  # type: ignore
#      79         **kwargs,  # type: ignore
#      80     )
#      81 self._index_struct = index_struct
#      82 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/base.py:185, in BaseIndex.build_index_from_nodes(self, nodes, **build_kwargs)
#     183 """Build the index from nodes."""
#     184 self._docstore.add_documents(nodes, allow_update=True)
# --> 185 return self._build_index_from_nodes(nodes, **build_kwargs)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/keyword_table/base.py:180, in BaseKeywordTableIndex._build_index_from_nodes(self, nodes, **build_kwargs)
#     178     run_async_tasks(tasks)
#     179 else:
# --> 180     self._add_nodes_to_index(index_struct, nodes, self._show_progress)
#     182 return index_struct
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/keyword_table/base.py:147, in BaseKeywordTableIndex._add_nodes_to_index(self, index_struct, nodes, show_progress)
#     143 nodes_with_progress = get_tqdm_iterable(
#     144     nodes, show_progress, "Extracting keywords from nodes"
#     145 )
#     146 for n in nodes_with_progress:
# --> 147     keywords = self._extract_keywords(
#     148         n.get_content(metadata_mode=MetadataMode.LLM)
#     149     )
#     150     index_struct.add_node(list(keywords), n)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/indices/keyword_table/base.py:236, in KeywordTableIndex._extract_keywords(self, text)
#     234 def _extract_keywords(self, text: str) -> Set[str]:
#     235     """Extract keywords from text."""
# --> 236     response = self._llm.predict(
#     237         self.keyword_extract_template,
#     238         text=text,
#     239     )
#     240     return extract_keywords_given_response(response, start_token="KEYWORDS:")
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:311, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     308             _logger.debug(f"Failed to reset active_span_id: {e}")
#     310 try:
# --> 311     result = func(*args, **kwargs)
#     312     if isinstance(result, asyncio.Future):
#     313         # If the result is a Future, wrap it
#     314         new_future = asyncio.ensure_future(result)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/llms/llm.py:596, in LLM.predict(self, prompt, **prompt_args)
#     594 if self.metadata.is_chat_model:
#     595     messages = self._get_messages(prompt, **prompt_args)
# --> 596     chat_response = self.chat(messages)
#     597     output = chat_response.message.content or ""
#     598 else:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:311, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     308             _logger.debug(f"Failed to reset active_span_id: {e}")
#     310 try:
# --> 311     result = func(*args, **kwargs)
#     312     if isinstance(result, asyncio.Future):
#     313         # If the result is a Future, wrap it
#     314         new_future = asyncio.ensure_future(result)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/core/llms/callbacks.py:173, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     164 event_id = callback_manager.on_event_start(
#     165     CBEventType.LLM,
#     166     payload={
#    (...)
#     170     },
#     171 )
#     172 try:
# --> 173     f_return_val = f(_self, messages, **kwargs)
#     174 except BaseException as e:
#     175     callback_manager.on_event_end(
#     176         CBEventType.LLM,
#     177         payload={EventPayload.EXCEPTION: e},
#     178         event_id=event_id,
#     179     )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/llama_index/llms/ollama/base.py:286, in Ollama.chat(self, messages, **kwargs)
#     282 ollama_messages = self._convert_to_ollama_messages(messages)
#     284 tools = kwargs.pop("tools", None)
# --> 286 response = self.client.chat(
#     287     model=self.model,
#     288     messages=ollama_messages,
#     289     stream=False,
#     290     format="json" if self.json_mode else "",
#     291     tools=tools,
#     292     options=self._model_kwargs,
#     293     keep_alive=self.keep_alive,
#     294 )
#     296 tool_calls = response["message"].get("tool_calls", [])
#     297 token_counts = self._get_response_token_counts(response)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ollama/_client.py:236, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     233   if images := message.get('images'):
#     234     message['images'] = [_encode_image(image) for image in images]
# --> 236 return self._request_stream(
#     237   'POST',
#     238   '/api/chat',
#     239   json={
#     240     'model': model,
#     241     'messages': messages,
#     242     'tools': tools or [],
#     243     'stream': stream,
#     244     'format': format,
#     245     'options': options or {},
#     246     'keep_alive': keep_alive,
#     247   },
#     248   stream=stream,
#     249 )
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ollama/_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ollama/_client.py:70, in Client._request(self, method, url, **kwargs)
#      69 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 70   response = self._client.request(method, url, **kwargs)
#      72   try:
#      73     response.raise_for_status()
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_transports/default.py:235, in HTTPTransport.handle_request(self, request)
#     221 assert isinstance(request.stream, SyncByteStream)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
# --> 235 with map_httpcore_exceptions():
#     236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/httpx/_transports/default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ReadTimeout: timed out

# %%
documents[2]
# Out:
# Document(id_='130e02fe-2d9f-453b-9483-0a24c875bd97', embedding=None, metadata={'page_label': 'iii', 'file_name': '80K_HOURS_final.pdf', 'file_path': '/workspace/GenieCraft/RAGwLlamaIndex/data/80K_HOURS_final.pdf', 'file_type': 'application/pdf', 'file_size': 6929338, 'creation_date': '2024-11-10', 'last_modified_date': '2024-11-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='FIND A FULFILLING CAREER  \nTHAT DOES GOOD\nBENJAMIN TODD\nAND THE 80,000 HOURS TEAM', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')
